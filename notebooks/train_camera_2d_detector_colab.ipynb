# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !git clone https://github.com/yharidy/object_detection.git

# %%
# %cd object_detection

# %%
# !pip install -r requirements.txt -q

# %%
# !pip install -e .

# %%
from google.colab import userdata
import wandb
wandb.login(key=userdata.get("WANDB_API_KEY"))

# %%
# !export DATA_ROOT="gs://waymo_open_dataset_v_2_0_1"
# !export N_SEGMENTS=10

# %%
# !python scripts/train_camera_2d.py
